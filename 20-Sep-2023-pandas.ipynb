# %%
import pandas as pd

# %%
data = {"Jan": 31, "Feb": 28, "Mar": 31}

# %%
print(data)
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31}

# %%
data_df=pd.DataFrame(data, index = ['1', '2', '3'])

# %%
data_df.head()
# Out:
#    Jan  Feb  Mar
# 1   31   28   31
# 2   31   28   31
# 3   31   28   31

# %%
new_data=pd.read_csv("Pandas_datasets/IMDB-Movie-Data.csv", index_col=0)

# %%
new_data.head(10)
# Out:
#                         Title                       Genre  \
# Rank
# 1     Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 2                  Prometheus    Adventure,Mystery,Sci-Fi
# 3                       Split             Horror,Thriller
# 4                        Sing     Animation,Comedy,Family
# 5               Suicide Squad    Action,Adventure,Fantasy
# 6              The Great Wall    Action,Adventure,Fantasy
# 7                  La La Land          Comedy,Drama,Music
# 8                    Mindhorn                      Comedy
# 9          The Lost City of Z  Action,Adventure,Biography
# 10                 Passengers     Adventure,Drama,Romance
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
new_data.tail(10)
# Out:
#                                Title                     Genre  \
# Rank
# 991   Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 992                 Taare Zameen Par        Drama,Family,Music
# 993             Take Me Home Tonight      Comedy,Drama,Romance
# 994         Resident Evil: Afterlife   Action,Adventure,Horror
# 995                        Project X                    Comedy
# 996             Secret in Their Eyes       Crime,Drama,Mystery
# 997                  Hostel: Part II                    Horror
# 998           Step Up 2: The Streets       Drama,Music,Romance
# 999                     Search Party          Adventure,Comedy
# 1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                             Description            Director  \
# Rank
# 991   An origins story centered on the centuries-old...  Patrick Tatopoulos
# 992   An eight-year-old boy is thought to be a lazy ...          Aamir Khan
# ...

# %%
movieDF=new_data

# %%
movieDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
tempDF=new_data.append(new_data)
# Out:
# /tmp/ipykernel_1672/2324581791.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempDF=new_data.append(new_data)

# %%
tempDF.shape
# Out:
# (2000, 11)

# %%
tempDF=tempDF.drop_duplicates()

# %%
tempDF.shape
# Out:
# (1000, 11)

# %%
tempDF=new_data.append(new_data)
# Out:
# /tmp/ipykernel_1672/2324581791.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tempDF=new_data.append(new_data)

# %%
tempDF.shape
# Out:
# (2000, 11)

# %%
tempDF.drop_duplicates(keep=False)
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Description, Director, Actors, Year, Runtime (Minutes), Rating, Votes, Revenue (Millions), Metascore]
# Index: []

# %%
tempDF.shape
# Out:
# (2000, 11)

# %%
tempDF.drop_duplicates(keep="last")
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
tempDF.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
tempDF.rename(columns={'Runtime (Minutes)':"Runtime", 'Revenue (Millions)': "Revenue"},inplace=True)

# %%
tempDF.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
lower_case_col = [x.lower() for x in tempDF.columns]

# %%
print(lower_case_col)
# Out:
# ['title', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 'rating', 'votes', 'revenue', 'metascore']

# %%
tempDF.isnull()
# Out:
#       Title  Genre  Description  Director  Actors   Year  Runtime  Rating  \
# Rank
# 1     False  False        False     False   False  False    False   False
# 2     False  False        False     False   False  False    False   False
# 3     False  False        False     False   False  False    False   False
# 4     False  False        False     False   False  False    False   False
# 5     False  False        False     False   False  False    False   False
# ...     ...    ...          ...       ...     ...    ...      ...     ...
# 996   False  False        False     False   False  False    False   False
# 997   False  False        False     False   False  False    False   False
# 998   False  False        False     False   False  False    False   False
# 999   False  False        False     False   False  False    False   False
# 1000  False  False        False     False   False  False    False   False
#
#       Votes  Revenue  Metascore
# Rank
# 1     False    False      False
# ...

# %%
tempDF.isnull().sum()
# Out:
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        256
# Metascore      128
# dtype: int64

# %%
tempDF.dropna()
# Out:
#                          Title                     Genre  \
# Rank
# 1      Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                   Prometheus  Adventure,Mystery,Sci-Fi
# 3                        Split           Horror,Thriller
# 4                         Sing   Animation,Comedy,Family
# 5                Suicide Squad  Action,Adventure,Fantasy
# ...                        ...                       ...
# 994   Resident Evil: Afterlife   Action,Adventure,Horror
# 995                  Project X                    Comedy
# 997            Hostel: Part II                    Horror
# 998     Step Up 2: The Streets       Drama,Music,Romance
# 1000                Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
tempDF.isnull().sum()
# Out:
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        256
# Metascore      128
# dtype: int64

# %%
tempDF.drop_duplicates(inplace=True)
tempDF.dropna(inplace=True)

# %%
tempDF.isnull().sum()
# Out:
# Title          0
# Genre          0
# Description    0
# Director       0
# Actors         0
# Year           0
# Runtime        0
# Rating         0
# Votes          0
# Revenue        0
# Metascore      0
# dtype: int64

# %%
revenue = tempDF['Revenue']

# %%
type(tempDF)
# Out:
# pandas.core.frame.DataFrame

# %%
type(revenue)
# Out:
# pandas.core.series.Series

# %%
tempDF=new_data

# %%
tempDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
meta_mean=tempDF['Metascore'].mean()

# %%
print(meta_mean)
# Out:
# 58.98504273504273

# %%
metascore=tempDF['Metascore']

# %%
metascore.fillna(meta_mean,inplace=True)

# %%
tempDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           1000 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
tempDF.rename(columns={'Runtime (Minutes)':"Runtime", 'Revenue (Millions)': "Revenue"},inplace=True)

# %%
tempDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1000 non-null   object
#  1   Genre        1000 non-null   object
#  2   Description  1000 non-null   object
#  3   Director     1000 non-null   object
#  4   Actors       1000 non-null   object
#  5   Year         1000 non-null   int64
#  6   Runtime      1000 non-null   int64
#  7   Rating       1000 non-null   float64
#  8   Votes        1000 non-null   int64
#  9   Revenue      872 non-null    float64
#  10  Metascore    1000 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
revenue=tempDF['Revenue']

# %%
revenue_mean=revenue.mean()

# %%
revenue.fillna(revenue_mean,inplace=True)

# %%
tempDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1000 non-null   object
#  1   Genre        1000 non-null   object
#  2   Description  1000 non-null   object
#  3   Director     1000 non-null   object
#  4   Actors       1000 non-null   object
#  5   Year         1000 non-null   int64
#  6   Runtime      1000 non-null   int64
#  7   Rating       1000 non-null   float64
#  8   Votes        1000 non-null   int64
#  9   Revenue      1000 non-null   float64
#  10  Metascore    1000 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
tempDF.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tempDF.describe()
#
# NameError: name 'tempDF' is not defined

# %%
tempDF=new_data

# %%
tempDF['Metascore'].describe()
# Out:
# count    936.000000
# mean      58.985043
# std       17.194757
# min       11.000000
# 25%       47.000000
# 50%       59.500000
# 75%       72.000000
# max      100.000000
# Name: Metascore, dtype: float64

# %%
tempDF['Metascore'].value_counts()
# Out:
# 72.0    25
# 68.0    25
# 66.0    25
# 64.0    24
# 57.0    23
#         ..
# 19.0     1
# 98.0     1
# 16.0     1
# 91.0     1
# 11.0     1
# Name: Metascore, Length: 84, dtype: int64

# %%
tempDF[tempDF['Rating']>8.0]
# Out:
#                                              Title  \
# Rank
# 1                          Guardians of the Galaxy
# 7                                       La La Land
# 17                                   Hacksaw Ridge
# 19                                            Lion
# 27                         Bahubali: The Beginning
# 37                                    Interstellar
# 51      Star Wars: Episode VII - The Force Awakens
# 55                                 The Dark Knight
# 65                                    The Prestige
# 68                              Mad Max: Fury Road
# 75                                        Zootopia
# 77                                    The Avengers
# 78                            Inglourious Basterds
# 81                                       Inception
# 83                         The Wolf of Wall Street
# 84                                       Gone Girl
# 91                                       Prisoners
# ...

# %%
tempDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
def goodMovies(dataframe):
    return dataframe[dataframe['Rating']>8.0]

# %%
good_movies = goodMovies(tempDF)

# %%
display(good_movies)
# Out:
#                                              Title  \
# Rank
# 1                          Guardians of the Galaxy
# 7                                       La La Land
# 17                                   Hacksaw Ridge
# 19                                            Lion
# 27                         Bahubali: The Beginning
# 37                                    Interstellar
# 51      Star Wars: Episode VII - The Force Awakens
# 55                                 The Dark Knight
# 65                                    The Prestige
# 68                              Mad Max: Fury Road
# 75                                        Zootopia
# 77                                    The Avengers
# 78                            Inglourious Basterds
# 81                                       Inception
# 83                         The Wolf of Wall Street
# 84                                       Gone Girl
# 91                                       Prisoners
# ...

# %%
def movieRating(rating):
    if rating >=8.0:
        return "Good"
    else:
        return "Bad"

# %%
tempDF['is it Good?']=tempDF['Rating'].apply(movieRating)

# %%
display(tempDF)
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
tempDF.plot(kind='scatter', x='Rating', y='Revenue (Millions)', title='Revenue vs Rating')
# Out:
# <Axes: title={'center': 'Revenue vs Rating'}, xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
tempDF.plot(kind='bar', x='Rating', y='Revenue (Millions)', title='Revenue vs Rating')
# Out:
# <Axes: title={'center': 'Revenue vs Rating'}, xlabel='Rating'>
